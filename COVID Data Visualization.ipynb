# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.read_csv('./data/covid_19_data.csv')
df
# Out:
#        SNo ObservationDate                Province/State  \
# 0        1      01/22/2020                         Anhui
# 1        2      01/22/2020                       Beijing
# 2        3      01/22/2020                     Chongqing
# 3        4      01/22/2020                        Fujian
# 4        5      01/22/2020                         Gansu
# ...    ...             ...                           ...
# 5627  5628      03/14/2020          Virgin Islands, U.S.
# 5628  5629      03/14/2020                     Gibraltar
# 5629  5630      03/14/2020  Diamond Princess cruise ship
# 5630  5631      03/14/2020                 West Virginia
# 5631  5632      03/14/2020                           NaN
#
#                       Country/Region          Last Update  Confirmed  Deaths  \
# 0                     Mainland China      1/22/2020 17:00        1.0     0.0
# 1                     Mainland China      1/22/2020 17:00       14.0     0.0
# ...

# %%
df_cases = df[['ObservationDate', 'Confirmed', 'Deaths', 'Recovered']]
df_grouped = df_cases.groupby('ObservationDate').sum()
df_grouped['Sick'] = df_grouped['Confirmed'] - df_grouped['Deaths'] - df_grouped['Recovered']

# %%
df_grouped
# Out:
#                  Confirmed  Deaths  Recovered     Sick
# ObservationDate
# 01/22/2020           555.0    17.0       28.0    510.0
# 01/23/2020           653.0    18.0       30.0    605.0
# 01/24/2020           941.0    26.0       36.0    879.0
# 01/25/2020          1438.0    42.0       39.0   1357.0
# 01/26/2020          2118.0    56.0       52.0   2010.0
# 01/27/2020          2927.0    82.0       61.0   2784.0
# 01/28/2020          5578.0   131.0      107.0   5340.0
# 01/29/2020          6165.0   133.0      126.0   5906.0
# 01/30/2020          8235.0   171.0      143.0   7921.0
# 01/31/2020          9925.0   213.0      222.0   9490.0
# 02/01/2020         12038.0   259.0      284.0  11495.0
# 02/02/2020         16787.0   362.0      472.0  15953.0
# 02/03/2020         19881.0   426.0      623.0  18832.0
# 02/04/2020         23892.0   492.0      852.0  22548.0
# 02/05/2020         27636.0   564.0     1124.0  25948.0
# 02/06/2020         30818.0   634.0     1487.0  28697.0
# ...

# %%
df_grouped.plot()
